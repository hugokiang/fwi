# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
nx = 350
nz = 200

# %%
# gera a matriz
v = np.zeros((nx, nz), dtype='float32')
v[:,0:51] = 1500
v[:,51:101] = 2000
v[:,101:185] = 2500
v[:,185:200] = 3000

# %%
v = v.reshape((nx, nz))
plt.imshow(v.T, aspect='auto')
plt.colorbar()
plt.show()

# %%
v.tofile("camadas.bin")

# %% [markdown]
# # Gera arquivo de aquisição

# %%
lista = []

# adiciona fonte
lista.append([30., 1750., 0., 0., 0.])
rz = 20
dx = 10
xi = 0
rx = xi
while rx <= 3500.:
    lista.append([rz, rx, 0., 0., 0.])
    rx += dx
lista = np.array(lista)

# %%
np.savetxt("aquisicao", lista, fmt='%5.1f')

# %% [markdown]
# # Gera modelo inicial

# %%
# gera a matriz
v0 = np.zeros((nx, nz), dtype='float32')
v0 = v0.reshape((nx, nz))
v0[:,0:51] = 1500
grad = np.linspace(1500, 3000, 150)
print grad.shape
#v0[:,50:200]=2000
#v0[:,50:200]=grad
v0.tofile("fv0")
# Out:
# (150,)

# %%
v0 = np.fromfile("m0.dat", dtype=np.float32)
v0 = v0.reshape((nx, nz))
plt.imshow(v0.T, aspect='auto')
plt.colorbar()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-11-118d8c024491> in <module>()
# ----> 1 v0 = np.fromfile("m0.dat", dtype=np.float32)
#       2 v0 = v0.reshape((nx, nz))
#       3 plt.imshow(v0.T, aspect='auto')
#       4 plt.colorbar()
#       5 plt.show()
#
# IOError: [Errno 2] No such file or directory: 'm0.dat'

# %%
plt.imshow(v.T, aspect='auto')
plt.colorbar()
plt.show()

# %%
v0.tofile("fv0")

# %%
# arquivo de densidades
# gera a matriz
rho = np.zeros((nx, nz), dtype='float32')
rho = rho.reshape((nx, nz))
rho = rho+2000.0
rho.tofile("frho")

# %% [markdown]
# # Exemplo de saída com um tiro

# %%
a = np.fromfile("modelo-it0.dat", dtype=np.float32)
a = a.reshape((nx, nz))
plt.imshow(a.T, aspect='auto')
plt.colorbar()
plt.show()

# %%
a = np.fromfile("modelo-it199.dat", dtype=np.float32)
a = a.reshape((nx, nz))
plt.imshow(a.T, aspect='auto')
plt.colorbar()
plt.show()

# %% [markdown]
# # Gráfico de uma posicao

# %%
a = np.fromfile("modelo-it50.dat", dtype=np.float32)
a = a.reshape((nx, nz))
col=nx/2
lin = a[col,:]
lv = v[col,:]
plt.plot(lin)
v0 =np.zeros(50)
v0 = 1500+v0
v0 = np.concatenate((v0, grad))
plt.plot(lv)
plt.plot(v0)
plt.show()

# %%
a = np.fromfile("modelo-it68.dat", dtype=np.float32)
a = a.reshape((nx, nz))
col=nx/2
lin = a[col,:]
lv = v[col,:]
plt.plot(lin)
v0 =np.zeros(50)
v0 = 1500+v0
v0 = np.concatenate((v0, grad))
plt.plot(lv)
plt.plot(v0)
plt.show()

# %% [markdown]
# # Gera arquivos de aquisição

# %%
sz = 30.
sx = 40.
dsx = 250.
drx = 20
rz = 20.
tiro=0
while sx < 3500.:
    lista = []
    # adiciona fonte
    lista.append([sz, sx, 0., 0., 0.])
    xi = 20
    rx = xi
    while rx < 3500.:
        lista.append([rz, rx, 0., 0., 0.])
        rx += drx
    lista = np.array(lista)
    nome="aquis/tiro"+str(tiro)
    np.savetxt(nome, lista, fmt='%5.1f')  
    tiro+=1
    sx += dsx

# %%
ntracos=350
ns = 3000
tr = np.fromfile("traces.dat", dtype=np.float32)
tr = tr.reshape((ntracos, ns))
tr0 = np.fromfile("traces0.dat", dtype=np.float32)
tr0 = tr0.reshape((ntracos, ns))
plt.imshow(tr.T, aspect='auto')
plt.colorbar()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-44-b8851e88730e> in <module>()
#       2 ns = 3000
#       3 tr = np.fromfile("traces.dat", dtype=np.float32)
# ----> 4 tr = tr.reshape((ntracos, ns))
#       5 tr0 = np.fromfile("traces0.dat", dtype=np.float32)
#       6 tr0 = tr0.reshape((ntracos, ns))
#
# ValueError: total size of new array must be unchanged

# %%
plt.imshow((tr-tr0).T, aspect='auto')
plt.colorbar()
plt.show()
